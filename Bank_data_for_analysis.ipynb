# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
bank_data = pd.read_csv(r'C:\Users\YASHA\Downloads\bank-additional-full.csv', sep=';')
final_data = pd.read_csv(r'C:\Users\YASHA\Downloads\bank-additional-full.csv', sep=';')

# %%
from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all"

# %%
# bank_data = final_data  it is type of shallow copy if we change one, other will also change..it is just the pointer

# %%
bank_data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
bank_data.shape
final_data.shape
# Out:
# (41188, 21)
# (38245, 21)

# %%
bank_data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
bank_data.describe().transpose()
# Out:
#                   count         mean         std       min       25%  \
# age             41188.0    40.024060   10.421250    17.000    32.000
# duration        41188.0   258.285010  259.279249     0.000   102.000
# campaign        41188.0     2.567593    2.770014     1.000     1.000
# pdays           41188.0   962.475454  186.910907     0.000   999.000
# previous        41188.0     0.172963    0.494901     0.000     0.000
# emp.var.rate    41188.0     0.081886    1.570960    -3.400    -1.800
# cons.price.idx  41188.0    93.575664    0.578840    92.201    93.075
# cons.conf.idx   41188.0   -40.502600    4.628198   -50.800   -42.700
# euribor3m       41188.0     3.621291    1.734447     0.634     1.344
# nr.employed     41188.0  5167.035911   72.251528  4963.600  5099.100
#
#                      50%       75%       max
# age               38.000    47.000    98.000
# duration         180.000   319.000  4918.000
# campaign           2.000     3.000    56.000
# ...

# %%
bank_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
# age               41188 non-null int64
# job               41188 non-null object
# marital           41188 non-null object
# education         41188 non-null object
# default           41188 non-null object
# housing           41188 non-null object
# loan              41188 non-null object
# contact           41188 non-null object
# month             41188 non-null object
# day_of_week       41188 non-null object
# duration          41188 non-null int64
# campaign          41188 non-null int64
# pdays             41188 non-null int64
# previous          41188 non-null int64
# poutcome          41188 non-null object
# emp.var.rate      41188 non-null float64
# cons.price.idx    41188 non-null float64
# cons.conf.idx     41188 non-null float64
# euribor3m         41188 non-null float64
# nr.employed       41188 non-null float64
# y                 41188 non-null object
# ...

# %%
bank_data.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
sns.countplot(y = 'job', data = bank_data)

# %%
sns.countplot(y = 'job', data = final_data)

# %%
final_data = final_data[final_data.job != 'unknown']
final_data.shape
# Out:
# (38245, 21)

# %%
sns.countplot(y='job', data = final_data)

# %%
sns.countplot(x = 'loan', data = final_data)

# %%
final_data = final_data[final_data.loan != 'unknown']

# %%
sns.countplot(x = 'contact', data = bank_data)

# %%
final_data.shape
# Out:
# (39873, 21)

# %%
sns.countplot(data = bank_data, x = 'contact', hue ='y')

# %%
sns.countplot(x = 'y', data = bank_data)

# %%
bank_data['contact'].value_counts()
# Out:
# cellular     26144
# telephone    15044
# Name: contact, dtype: int64

# %%
df = bank_data.groupby(by = 'contact')

# %%
df['y'].value_counts()
# Out:
# contact    y
# cellular   no     22291
#            yes     3853
# telephone  no     14257
#            yes      787
# Name: y, dtype: int64

# %%
df['y'].value_counts()[0]
df['y'].value_counts()[1]
df['y'].value_counts()[2]
df['y'].value_counts()[3]
# Out:
# 22291
# 3853
# 14257
# 787

# %%
df['y'].value_counts()[1]/(df['y'].value_counts()[1] + df['y'].value_counts()[0])

# ration of yes cellular
# Out:
# 0.14737607099143207

# %%
df['y'].value_counts()[3]/(df['y'].value_counts()[3] + df['y'].value_counts()[2])
# ratio of yes in cellular
# Out:
# 0.05231321457059293

# %%
# other way from the traditional approach is
cell =  df['y'].value_counts()[1]/df['contact'].value_counts()[0]
cell
# Out:
# 0.14737607099143207

# %%
tele = df['y'].value_counts()[3]/df['contact'].value_counts()[1]
tele
# Out:
# 0.05231321457059293

# %%
 type(tele)
    # to check whether it is of numpy object or series
# Out:
# numpy.float64

# %%
dt = np.array([cell ,tele]).T
dt
# Out:
# array([0.14737607, 0.05231321])

# %%
ser = pd.DataFrame(dt).T

# %%
ser.columns = ('cellular','telephone')
ser
# Out:
#    cellular  telephone
# 0  0.147376   0.052313

# %%
ser.plot(kind= 'bar')

# %%
sns.countplot(x = 'y', data = bank_data)

# %%
sns.countplot(x = 'marital', data = bank_data)

# %%
sns.countplot(x = 'marital', hue= 'y', data = bank_data)

# %%
final_data = final_data[final_data.marital != 'unknown']

# %%
bank_data.education.value_counts()
sns.countplot(y ='education', data=bank_data)

## make it into 2 categories  cat 1 : with above high school cat 2 : with below high school and conversion rate  plot
# Out:
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: education, dtype: int64

# %%
# we are droping the illliterates for now but we can check what is the conversion rate
final_data = final_data[final_data.education != 'illliterate']
final_data.shape
# Out:
# (38245, 21)

# %%
df = final_data.groupby('education')

# %%
df['y'].value_counts()
# Out:
# education            y
# basic.4y             no      3590
#                      yes      412
# basic.6y             no      2024
#                      yes      180
# basic.9y             no      5399
#                      yes      457
# high.school          no      8237
#                      yes     1007
# illiterate           no        14
#                      yes        4
# professional.course  no      4522
#                      yes      578
# university.degree    no     10201
#                      yes     1620
# unknown              no      1329
#                      yes      229
# Name: y, dtype: int64

# %%
final_data = final_data[final_data.education != 'unknown']
final_data.shape
# Out:
# (38245, 21)

# %%
sns.countplot(x = 'default', data = bank_data)

# %%
final_data = final_data[final_data.education != 'unknown']
# this is not at all recomded as it has lots of value

# %%
final_data.shape
# Out:
# (38245, 21)

# %%
sns.countplot(x= 'housing', data =bank_data)

# %%
sns.countplot(x = 'y', data = bank_data)

# %%
sns.countplot(x= 'month', data = bank_data)

# %%
sns.countplot(x= 'month', data = bank_data, hue = 'y' )

# %%
sns.countplot(x = 'default', data= bank_data)

# %%
 bank_data['duration']
# Out:
# 0         261
# 1         149
# 2         226
# 3         151
# 4         307
# 5         198
# 6         139
# 7         217
# 8         380
# 9          50
# 10         55
# 11        222
# 12        137
# 13        293
# 14        146
# 15        174
# 16        312
# 17        440
# 18        353
# 19        195
# 20         38
# 21        262
# 22        342
# 23        181
# 24        172
# 25         99
# 26         93
# 27        233
# 28        255
# 29        362
#          ...
# 41158     363
# 41159     514
# 41160     843
# 41161     510
# 41162     347
# 41163     385
# 41164    1868
# 41165     403
# 41166     651
# 41167     236
# 41168     144
# 41169     154
# 41170     293
# 41171     112
# 41172     353
# 41173     329
# 41174     208
# 41175     180
# 41176     360
# 41177     124
# 41178     483
# 41179     151
# 41180     254
# 41181     281
# 41182     112
# 41183     334
# 41184     383
# 41185     189
# 41186     442
# 41187     239
# ...

# %%
 bank_data['duration'].describe()
# Out:
# count    41188.000000
# mean       258.285010
# std        259.279249
# min          0.000000
# 25%        102.000000
# 50%        180.000000
# 75%        319.000000
# max       4918.000000
# Name: duration, dtype: float64

# %%
# How to make categories in data
sns.countplot(x='duration', data = bank_data)

# %%
bank_data['duration'].argmax()
# Out:
# C:\Users\YASHA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# 24091

# %%
bank_data.iloc[bank_data['duration'].argmax()]
# Out:
# C:\Users\YASHA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# age                                33
# job                        technician
# marital                        single
# education         professional.course
# default                            no
# housing                           yes
# loan                               no
# contact                     telephone
# month                             nov
# day_of_week                       mon
# duration                         4918
# campaign                            1
# pdays                             999
# previous                            0
# ...

# %%
bank_data['y'].iloc[bank_data['duration'].argmax()]
# Out:
# C:\Users\YASHA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# 'no'

# %%
bank_data['y'].iloc[max(bank_data['duration'])]
# same thing
# Out:
# 'no'

# %%
bank_data['duration'] = bank_data['duration']/60
duration_list = pd.cut(bank_data['duration'],[0,0.1,0.2,0.3,0.4,100]).rename('dur_interval')
duration_list = pd.concat([duration_list,bank_data['y']], axis = 1)         

sns.factorplot(data = duration_list, x='dur_interval',hue ='y', kind = 'count')
plt.xlabel('Duration of call (in mins)')
plt.ylabel('No of Calls made')
plt.title('Calls effectiveness w.r.t. duration')
plt.subplots_adjust(top = 0.9)
# Out:
# C:\Users\YASHA\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.5, 21.70625000000002, 'Duration of call (in mins)')
# Text(14.092291666666668, 0.5, 'No of Calls made')
# Text(0.5, 1.0, 'Calls effectiveness w.r.t. duration')

# %%
dummy_df =pd.get_dummies(final_data['y'])
temp_data = pd.concat([final_data, dummy_df['yes']], axis =1)
corr = temp_data.corr()

plt.figure()
sns.heatmap(corr, linewidths = 1, cmap ='coolwarm')
plt.title('Correlation of non-categorical variable to the decision')
# Out:
# Text(0.5, 1.0, 'Correlation of non-categorical variable to the decision')

# %%
dummy_df =pd.get_dummies(final_data['y'])
temp_data = pd.concat([final_data, dummy_df['yes']], axis = 1)
corr = temp_data.corr()
corr
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000  0.002405  0.005519 -0.038476  0.028479
# duration        0.002405  1.000000 -0.071110 -0.044278  0.016304
# campaign        0.005519 -0.071110  1.000000  0.051536 -0.078478
# pdays          -0.038476 -0.044278  0.051536  1.000000 -0.581303
# previous        0.028479  0.016304 -0.078478 -0.581303  1.000000
# emp.var.rate   -0.003563 -0.025003  0.150752  0.268705 -0.419647
# cons.price.idx -0.001236  0.007530  0.128665  0.080828 -0.208783
# cons.conf.idx   0.127644 -0.008656 -0.010713 -0.090587 -0.056856
# euribor3m       0.007695 -0.029029  0.134783  0.291953 -0.450672
# nr.employed    -0.021054 -0.040722  0.143150  0.366783 -0.494617
# yes             0.030130  0.405832 -0.065117 -0.319351  0.221159
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.003563       -0.001236       0.127644   0.007695
# ...

# %%
dummy_df =pd.get_dummies(bank_data['y'])
temp_data = pd.concat([bank_data, dummy_df['yes']], axis = 1)
corr = temp_data.corr()
corr
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000 -0.000866  0.004594 -0.034369  0.024365
# duration       -0.000866  1.000000 -0.071699 -0.047577  0.020640
# campaign        0.004594 -0.071699  1.000000  0.052584 -0.079141
# pdays          -0.034369 -0.047577  0.052584  1.000000 -0.587514
# previous        0.024365  0.020640 -0.079141 -0.587514  1.000000
# emp.var.rate   -0.000371 -0.027968  0.150754  0.271004 -0.420489
# cons.price.idx  0.000857  0.005312  0.127836  0.078889 -0.203130
# cons.conf.idx   0.129372 -0.008173 -0.013733 -0.091342 -0.050936
# euribor3m       0.010767 -0.032897  0.135133  0.296899 -0.454494
# nr.employed    -0.017725 -0.044703  0.144095  0.372605 -0.501333
# yes             0.030399  0.405274 -0.066357 -0.324914  0.230181
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.000371        0.000857       0.129372   0.010767
# ...

# %% [markdown]
# ## Categorizing the data frame
# Categorizing the dataframe and convert it numeric
# Label Encoding the data frame

# %%
label_data = final_data

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
label_data['job'] = le.fit_transform(label_data['job'])
label_data['marital'] = le.fit_transform(label_data['marital'])
# label_data['default'] = le.fit_transform(label_data['default'])
label_data['housing'] = le.fit_transform(label_data['housing'])
label_data['month'] = le.fit_transform(label_data['month'])
label_data['loan'] = le.fit_transform(label_data['loan'])
# label_data['contact'] = le.fit_transform(label_data['contact'])
label_data['day_of_week'] = le.fit_transform(label_data['day_of_week'])
# label_data['poutcome'] = le.fit_transform(label_data['poutcome'])
label_data['y'] = le.fit_transform(label_data['y'])

# %%
label_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38245 entries, 0 to 41187
# Data columns (total 18 columns):
# age               38245 non-null int64
# job               38245 non-null int64
# marital           38245 non-null int64
# education         38245 non-null object
# housing           38245 non-null int64
# loan              38245 non-null int64
# month             38245 non-null int64
# day_of_week       38245 non-null int64
# duration          38245 non-null int64
# campaign          38245 non-null int64
# pdays             38245 non-null int64
# previous          38245 non-null int64
# emp.var.rate      38245 non-null float64
# cons.price.idx    38245 non-null float64
# cons.conf.idx     38245 non-null float64
# euribor3m         38245 non-null float64
# nr.employed       38245 non-null float64
# y                 38245 non-null int32
# dtypes: float64(5), int32(1), int64(11), object(1)
# memory usage: 6.6+ MB

# %%
label_data.head()
# Out:
#    age  job  marital    education  housing  loan  month  day_of_week  \
# 0   56    3        1     basic.4y        0     0      6            1
# 1   57    7        1  high.school        0     0      6            1
# 2   37    7        1  high.school        1     0      6            1
# 3   40    0        1     basic.6y        0     0      6            1
# 4   56    7        1  high.school        0     1      6            1
#
#    duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       261         1    999         0           1.1          93.994
# 1       149         1    999         0           1.1          93.994
# 2       226         1    999         0           1.1          93.994
# 3       151         1    999         0           1.1          93.994
# 4       307         1    999         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  y
# 0          -36.4      4.857       5191.0  0
# 1          -36.4      4.857       5191.0  0
# ...

# %%
sns.countplot(x='poutcome', data = label_data )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-235848fb9b1e> in <module>
# ----> 1 sns.countplot(x='poutcome', data = label_data )
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
# ...

# %%
sns.countplot(x='contact', data = label_data , hue = 'y' )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-187-5cc5fa0df2e6> in <module>
# ----> 1 sns.countplot(x='contact', data = label_data , hue = 'y' )
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
# ...

# %%
label_data = label_data.drop(['default','poutcome','contact'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-188-ef2ecb5d44e5> in <module>
# ----> 1 label_data = label_data.drop(['default','poutcome','contact'], axis = 1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
label_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38245 entries, 0 to 41187
# Data columns (total 18 columns):
# age               38245 non-null int64
# job               38245 non-null int64
# marital           38245 non-null int64
# education         38245 non-null object
# housing           38245 non-null int64
# loan              38245 non-null int64
# month             38245 non-null int64
# day_of_week       38245 non-null int64
# duration          38245 non-null int64
# campaign          38245 non-null int64
# pdays             38245 non-null int64
# previous          38245 non-null int64
# emp.var.rate      38245 non-null float64
# cons.price.idx    38245 non-null float64
# cons.conf.idx     38245 non-null float64
# euribor3m         38245 non-null float64
# nr.employed       38245 non-null float64
# y                 38245 non-null int32
# dtypes: float64(5), int32(1), int64(11), object(1)
# memory usage: 6.6+ MB

# %%
label_data.shape
# Out:
# (38245, 18)

# %%
label_data.corr()
# Out:
#                      age       job   marital   housing      loan     month  \
# age             1.000000 -0.001502 -0.393659  0.000291 -0.006390 -0.024083
# job            -0.001502  1.000000  0.019210  0.005185 -0.012360 -0.036720
# marital        -0.393659  0.019210  1.000000  0.009651  0.005221 -0.011091
# housing         0.000291  0.005185  0.009651  1.000000  0.045077 -0.016928
# loan           -0.006390 -0.012360  0.005221  0.045077  1.000000 -0.007117
# month          -0.024083 -0.036720 -0.011091 -0.016928 -0.007117  1.000000
# day_of_week    -0.017282 -0.002870  0.003796  0.001921 -0.010177  0.025514
# duration        0.002405 -0.006929  0.004178 -0.009104  0.000280  0.005269
# campaign        0.005519 -0.006324 -0.006636 -0.010817  0.003914 -0.062154
# pdays          -0.038476 -0.021142 -0.032688 -0.009370  0.001874 -0.045056
# previous        0.028479  0.013135  0.032242  0.020837 -0.003268  0.102471
# ...

# %%
label_data.head()
# Out:
#    age  job  marital    education  housing  loan  month  day_of_week  \
# 0   56    3        1     basic.4y        0     0      6            1
# 1   57    7        1  high.school        0     0      6            1
# 2   37    7        1  high.school        1     0      6            1
# 3   40    0        1     basic.6y        0     0      6            1
# 4   56    7        1  high.school        0     1      6            1
#
#    duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       261         1    999         0           1.1          93.994
# 1       149         1    999         0           1.1          93.994
# 2       226         1    999         0           1.1          93.994
# 3       151         1    999         0           1.1          93.994
# 4       307         1    999         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  y
# 0          -36.4      4.857       5191.0  0
# 1          -36.4      4.857       5191.0  0
# ...
